# %%
import pandas as pd
import sqlalchemy as alch

from getpass import getpass # sistema seguro para gestión de contraseñas

# %%
allcards = pd.read_csv("../data/all_cards.csv", index_col = 0)
topcards = pd.read_csv("../data/top_cards.csv", index_col = 0)

# %%
allcards.sample()
# Out:
#                                  name                     type
# id_
# 43210483  Symphonic Warrior Guitariss  Pendulum Effect Monster  \
#
#                 frametype                                               desc
# id_
# 43210483  effect_pendulum  [ Pendulum Effect ] You can target 1 other "Sy...  \
#
#              race  archetype     atk    def  level attribute
# id_
# 43210483  Machine  Symphonic  1100.0  500.0    3.0      WIND  \
#
#                                                        url_  cardmarket_price
# id_
# 43210483  https://yugioh.fandom.com/wiki/Symphonic_Warri...              0.03  \
#
#           tcgplayer_price  ebay_price  amazon_price  coolstuffinc_price
# id_
# 43210483             0.12        0.99          0.45                0.25  \
#
#           mean_price
# id_
# 43210483       0.368

# %%
allcards.isnull().sum()
# Out:
# name                     0
# type                     0
# frametype                0
# desc                     0
# race                     1
# archetype             5364
# atk                   4426
# def                   4807
# level                 4807
# attribute             4426
# url_                     0
# cardmarket_price         0
# tcgplayer_price          0
# ebay_price               0
# amazon_price             0
# coolstuffinc_price       0
# mean_price               0
# dtype: int64

# %%
columna = 'race'
valores_nulos = allcards[allcards[columna].isnull()]
valores_nulos
# Out:
#                           name        type frametype
# id_
# 300302044  Believe in your Bro  Skill Card     skill  \
#
#                                                         desc race archetype
# id_
# 300302044  Once per turn, you can activate 1 of these Ski...  NaN       NaN  \
#
#            atk  def  level attribute
# id_
# 300302044  NaN  NaN    NaN       NaN  \
#
#                                                         url_
# id_
# 300302044  https://yugioh.fandom.com/wiki/Believe_in_your...  \
#
#            cardmarket_price  tcgplayer_price  ebay_price  amazon_price
# id_
# 300302044               0.0              0.1        0.99           0.0  \
#
#            coolstuffinc_price  mean_price
# id_
# 300302044                0.49       0.316

# %%
# almacenamos la contraseña en una variable de forma segura, para que nadie la pueda ver. 

password = getpass("Contraseña de MySQL: ")

# %%
# almacenamos el nombre de nuestra BBDD en una variable
db_name = "yu_gi_oh_cards"

# creamos la conexipn con MySQL
conexion = f"mysql+pymysql://root:{password}@localhost/{db_name}"

# %%
engine = alch.create_engine(conexion)

# %%
topcards
# Out:
#                                            name         decks porcentage
# id_
# 21044178                          Abyss Dweller  In 418 Decks   12.7556%
# 86066372                      Accesscode Talker  In 872 Decks   26.6097%
# 81555617                   Ad Libitum of Despia  In 163 Decks    4.9741%
# 62320425             Agido the Ancient Sentinel  In 203 Decks    6.1947%
# 87746184              Albion the Branded Dragon  In 243 Decks    7.4153%
# ...                                         ...           ...        ...
# 2563463                 Wandering Gryphon Rider  In 256 Decks    7.8120%
# 30680659        Water Enchantress of the Temple  In 264 Decks    8.0561%
# 99234526              White Dragon Wyverburster  In 143 Decks    4.3637%
# 45935145  Wollow, Founder of the Drudge Dragons  In 158 Decks    4.8215%
# 43202238            Yazi, Evil of the Yang Zing  In 165 Decks    5.0351%
#
# [200 rows x 3 columns]

# %%
topcards.isnull().sum()
# Out:
# name          0
# decks         0
# porcentage    0
# dtype: int64

# %%
allcards.loc[81555617]
# Out:
# name                                               Ad Libitum of Despia
# type                                                     Effect Monster
# frametype                                                        effect
# desc                  During your Main Phase: You can make all monst...
# race                                                              Fairy
# archetype                                                        Despia
# atk                                                              1500.0
# def                                                              2000.0
# level                                                               8.0
# attribute                                                          DARK
# url_                  https://yugioh.fandom.com/wiki/Ad_Libitum_of_D...
# cardmarket_price                                                   0.13
# tcgplayer_price                                                    0.19
# ebay_price                                                         2.59
# amazon_price                                                       2.21
# coolstuffinc_price                                                 0.39
# mean_price                                                        1.102
# Name: 81555617, dtype: object
